# %% [markdown]
# **変数の利用1**

# %%
a = 2 * 3
a
# Out:
# 6

# %% [markdown]
# **変数の利用2**

# %%
b = a *2
b
# Out:
# 12

# %% [markdown]
# **入力・処理・出力**

# %%
a = input( "a = " )
b = input( "b = " )
a = int( a )
b = int( b )
c = a*b
print( "a x b = ", c )
# Out:
# a = 5
# b = 98935
# a x b =  494675

# %% [markdown]
# **制御文を含むプログラムの例**

# %%
s = 0

for i in range(1,43457856):
  s = s + i

print(s)
# Out:
# 944292602329440

# %% [markdown]
# 8桁が限界でした。9桁だと膨大な時間がかかりました

# %%
s = 0
i = 1
while i<=100:
  s = s + i
  i += 1
print(s)
# Out:
# 5050
